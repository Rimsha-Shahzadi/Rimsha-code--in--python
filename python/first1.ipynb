# %% [markdown]
# # I am so happy

# %% [markdown]
# print("Hello World")

# %%
print("Rimsha")

# %%
print("Rimsha")
# Out:
# Rimsha

# %%
print("Pakistan")
print("Zinda Baad")
print("Zinda Baad")
print("Zinda Baad")
# Out:
# Pakistan
# Zinda Baad
# Zinda Baad
# Zinda Baad

# %%
print("Pakistan")
print("Zinda Baad")
print("Zinda Baad")
print("Zinda Baad")
# Out:
# Pakistan
# Zinda Baad
# Zinda Baad
# Zinda Baad

# %%
name: str = "Rimsha Shahzadi"
print(name)
print(type(name))
print(id(name))
# Out:
# Rimsha Shahzadi
# <class 'str'>
# 3050907981808

# %%
name: int = 200
print(name)
print(type(name))
print(id(name))
# Out:
# 200
# <class 'int'>
# 140735649307784

# %%
name: float = 20.5
print(name)
print(type(name))
print(id(name))
# Out:
# 20.5
# <class 'float'>
# 3050902567792

# %%
name: bool = True
print(name)
print(type(name))
print(id(name))
# Out:
# True
# <class 'bool'>
# 140735648416176

# %%
name: list[str] = ["Rimsha", "Jannat", "Ismail"]
print(name)
print(type(name))
print(id(name))
# Out:
# ['Rimsha', 'Jannat', 'Ismail']
# <class 'list'>
# 3050907281216

# %%
name: tuple[str, int, float] = ("Rimsha", 25, 26.5)
print(name)
print(type(name))
print(id(name))
# Out:
# ('Rimsha', 25, 26.5)
# <class 'tuple'>
# 3050907551616
